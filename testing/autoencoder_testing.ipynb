# %% [markdown]
# # Preprocessing data

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../src')
import ice

import numpy as np
import matplotlib.pyplot as plt
import sklearn
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, random_split
import pathlib
import datetime
from scipy.io import loadmat

# %%
# load simulation data
Eb = loadmat("../data/NGrIS/ensemble_data_pixelated/enthalpy_basal_grid.mat")['enthalpy_basal_grid']
Em = loadmat("../data/NGrIS/ensemble_data_pixelated/enthalpy_avg_grid.mat")['enthalpy_avg_grid']
pmp = loadmat("../data/NGrIS/ensemble_data_pixelated/pmp_grid.mat")['pmp_grid']
radar_mask = loadmat("../data/NGrIS/ensemble_data_pixelated/radar_mask.mat")['radar_mask']

Eb = np.array(Eb)
Em = np.array(Em)
pmp = pmp[:, :, np.newaxis]
pmp = np.tile(pmp, (1, 1, Eb.shape[2]))

# convert Em to attenu rate
Tb = ice.enthalpy_to_temperature(Eb, Tpmp = pmp, istorch = False)
Tm = ice.enthalpy_to_temperature(Em, Tpmp = pmp, istorch = False)

# # check for non convergent samples, generate graphs for each sample
# Tb_save_path = "../data/NGrIS/ensemble_data_pixelated/Eb_samples/"
# pathlib.Path(Tb_save_path).mkdir(parents=True, exist_ok=True)
# Tm_save_path = "../data/NGrIS/ensemble_data_pixelated/Em_samples/"
# pathlib.Path(Tm_save_path).mkdir(parents=True, exist_ok=True)

# for i in range(Tb.shape[2]):
#     fig, ax = plt.subplots()
#     im1 = ax.imshow(Tb[:, :, i], vmin = 240, vmax = 273.15)
#     plt.colorbar(im1)
#     ax.set_title(f"Eb sample {i+1}")
#     fig.savefig(f"{Tb_save_path}Tb_{i+1}.png")
#     plt.close(fig)

#     fig, ax = plt.subplots()
#     im2 = ax.imshow(Tm[:, :, i], vmin = 240, vmax = 273.15)
#     plt.colorbar(im2)
#     ax.set_title(f"Em sample {i+1}")
#     fig.savefig(f"{Tm_save_path}Tm_{i+1}.png")
#     plt.close(fig)

# remove samples that did not converge

# convert Tm to attenu rate
attenu = ice.temperature_to_atten_rate_ice(Tm)

non_convergence_idx = np.arange(attenu.shape[2])[np.all(np.isnan(attenu), axis = (0, 1))]
attenu = np.delete(attenu, non_convergence_idx, axis = 2)

transformer_Eb = sklearn.preprocessing.PowerTransformer()
transformer_attenu = sklearn.preprocessing.PowerTransformer()

Eb_standard = transformer_Eb.fit_transform(Eb.reshape(-1, 1))
Eb_standard = Eb_standard.reshape(int(np.sqrt(np.shape(Eb_standard)[0]/Eb.shape[2])), int(np.sqrt(np.shape(Eb_standard)[0]/Eb.shape[2])), Eb.shape[2])
attenu_fromEm_standard = transformer_attenu.fit_transform(attenu.reshape(-1, 1))
attenu_fromEm_standard = attenu_fromEm_standard.reshape(int(np.sqrt(np.shape(attenu_fromEm_standard)[0]/attenu.shape[2])), int(np.sqrt(np.shape(attenu_fromEm_standard)[0]/attenu.shape[2])), attenu.shape[2])

# filter points not on radar flight path
attenu_fromEm_standard[np.tile(radar_mask[:, :, np.newaxis], (1, 1, attenu_fromEm_standard.shape[2])) != 1] = 0
attenu_fromEm_standard = np.moveaxis(attenu_fromEm_standard, -1, 0)
attenu_fromEm_standard = attenu_fromEm_standard[:, np.newaxis, :, :]
attenu_fromEm_standard[np.isnan(attenu_fromEm_standard)] = 0
np.savez('attenu_fromEm_standard.npz', attenu_fromEm_standard = attenu_fromEm_standard)
attenu_fromEm_standard = torch.tensor(attenu_fromEm_standard).float()

Eb_standard = np.moveaxis(Eb_standard, -1, 0)
Eb_standard = Eb_standard[:, np.newaxis, :, :]
Eb_standard[np.isnan(Eb_standard)] = 0
np.savez('Eb_standard.npz', Eb_standard = Eb_standard)
Eb_standard = torch.tensor(Eb_standard).float()

# %%
var = np.nanvar(attenu_fromEm_standard, axis = 0)
im1 = plt.plot(var[0, :, :].flatten())

# %%
# attenu_shift = -torch.min(attenu_fromEm_standard)
# attenu_scale = 1 / (torch.max(attenu_fromEm_standard) - torch.min(attenu_fromEm_standard))

# Eb_shift = -torch.min(Eb_standard)
# Eb_scale = 1 / (torch.max(Eb_standard) - torch.min(Eb_standard))


# attenu_fromEm_standard = (attenu_fromEm_standard + attenu_shift) * attenu_scale
# Eb_standard = (Eb_standard + Eb_shift) * Eb_scale

# %%
# attenu_pca = sklearn.decomposition.PCA(n_components = 32)

# attenu_fromEm_dataset = TensorDataset(attenu_fromEm_standard, attenu_fromEm_standard)

# # train_size = int(0.7 * len(attenu_fromEm_standard))
# # val_size = int((len(attenu_fromEm_standard) - train_size)/2)
# # test_size = int(len(attenu_fromEm_standard) - train_size - val_size)

# # generator = torch.Generator().manual_seed(42)
# # attenu_fromEm_train_dataset, attenu_fromEm_val_dataset, attenu_fromEm_test_dataset = random_split(attenu_fromEm_dataset, [train_size, val_size, test_size], generator=generator)

# # torch.save(attenu_fromEm_train_dataset, 'attenu_fromEm_train_dataset.pt')
# # torch.save(attenu_fromEm_val_dataset, 'attenu_fromEm_val_dataset.pt')
# # torch.save(attenu_fromEm_test_dataset, 'attenu_fromEm_test_dataset.pt')

# attenu_pca.fit(attenu_fromEm_dataset[:][0].detach().numpy()[:, 0, :, :].reshape((-1, attenu_fromEm_dataset[:][0].shape[2] ** 2)))

# import joblib

# joblib.dump(attenu_pca, f'attenu_pca{datetime.datetime.now()}.pkl')

# %%
# attenu_fromEm_test_reconstruct = attenu_pca.inverse_transform(attenu_pca.transform(attenu_fromEm_test_dataset[:][0].detach().numpy()[:, 0, :, :].reshape((-1, attenu_fromEm_test_dataset[:][0].shape[2] ** 2))))
# attenu_fromEm_test_reconstruct = attenu_fromEm_test_reconstruct.reshape((-1, int(np.sqrt(attenu_fromEm_test_reconstruct.shape[1])), int(np.sqrt(attenu_fromEm_test_reconstruct.shape[1]))))

# plt.plot(attenu_fromEm_test_dataset[:][0].detach().numpy()[0, 0, :, :].flatten(), alpha = 0.5)
# plt.plot(attenu_fromEm_test_reconstruct[0, :, :].flatten(), alpha = 0.5, c = 'green')

# %%
plt.imshow(attenu_fromEm_standard[0, 0, :, :], vmin = -2, vmax = 2)

# %%
for i in range(0,  len(attenu_fromEm_standard), 10):
    plt.plot(attenu_fromEm_standard[i, 0, :, :].flatten())

# %%
# # load attenuation rate data from observation and generate samples assuming normal distribution
# attenu_mean = loadmat("../data/NGrIS/ensemble_data_pixelated/radar_attenu_rate_mean_grid.mat")['radar_attenu_rate_mean_grid']
# attenu_std = loadmat("../data/NGrIS/ensemble_data_pixelated/radar_attenu_rate_uncertainty_grid.mat")['radar_attenu_rate_uncertainty_grid']

# n_samples_attenu = 300
# # using shape suitable for tensor flow, n_sample * 1 * image dimension * image dimension
# attenu = np.zeros((n_samples_attenu, 1, attenu_mean.shape[0], attenu_mean.shape[1]))
# for i in range(n_samples_attenu):
#     attenu[i, 0, :, :] = np.random.normal(attenu_mean, attenu_std)

# attenu_fromEm_standard = attenu.copy()
# attenu_fromEm_standard = attenu_fromEm_standard - np.tile(attenu_mean[np.newaxis, np.newaxis, :, :], (n_samples_attenu, 1, 1, 1))
# attenu_fromEm_standard = attenu_fromEm_standard / np.tile(attenu_std[np.newaxis, np.newaxis, :, :], (n_samples_attenu, 1, 1, 1))
# attenu_fromEm_standard[np.isnan(attenu_fromEm_standard)] = 0
# attenu_fromEm_standard = torch.tensor(attenu_fromEm_standard).float()

# %% [markdown]
# # Autoencoder

# %%
class Autoencoder(nn.Module):

    def __init__(self, image_dimension, kernel_1_size = 3, h1_size = 256, h2_size = 128, h3_size = 32, output_size = 8):
      super(Autoencoder, self).__init__()

      dimension_after_conv = image_dimension - (kernel_1_size // 2) * 2 #- (kernel_2_size // 2) * 2

      self.encoder = nn.Sequential(
        nn.Conv2d(1, 1, kernel_1_size, 1),
        nn.ReLU(),
        # nn.Conv2d(1, 1, kernel_2_size, 1),
        # nn.ReLU(),
        nn.Flatten(start_dim=1),
        nn.Linear(dimension_after_conv ** 2, h1_size),
        nn.ReLU(),
        nn.Linear(h1_size, h2_size),
        nn.ReLU(),
        nn.Linear(h2_size, h3_size),
        nn.ReLU(),
        nn.Linear(h3_size, output_size)
      )
      self.decoder = nn.Sequential(
        nn.Linear(output_size, h3_size),
        nn.ReLU(),
        nn.Linear(h3_size, h2_size),
        nn.ReLU(),
        nn.Linear(h2_size, h1_size),
        nn.ReLU(),
        nn.Linear(h1_size, dimension_after_conv ** 2),
        nn.Unflatten(dim=1, unflattened_size = (1, dimension_after_conv, dimension_after_conv)),
        # nn.ReLU(),
        # nn.ConvTranspose2d(1, 1, kernel_2_size, 1),
        nn.ReLU(),
        nn.ConvTranspose2d(1, 1, kernel_1_size, 1),
      )
    
    def main(self, x):
       z = self.encoder(x)
       x = self.decoder(z)
       return x
    
# def flightpath_MSELoss(predictions, target, radar_mask):
#   # assuming input size of batch_size, 1, image_dimension, image_dimension
#   radar_mask_full = radar_mask.copy()[np.newaxis, np.newaxis, :, :]
#   radar_mask_full = np.tile(radar_mask_full, (predictions.shape[0], 1, 1, 1))
#   radar_mask_full = torch.tensor(radar_mask_full)

#   # add some non-zero but small weight to empty pixels
#   radar_mask_full[radar_mask_full == 0] = 0.5

#   predictions_flightpath = predictions * radar_mask_full
#   target_flightpath = target * radar_mask_full

#   return torch.nanmean((predictions_flightpath - target_flightpath) ** 2)

# def variance_MSELoss(predictions, target, variance_mask):
#   # assuming input size of batch_size, 1, image_dimension, image_dimension
#   # a MSE loss weighted on element-wise variance

#   # normalize variance_mask
#   variance_mask = variance_mask / (np.nanmax(variance_mask) - np.nanmin(variance_mask))

#   # add some small weight to variance mask where it is small
#   variance_mask[variance_mask <= 0.2] = 0.2

#   return torch.nanmean((((predictions - target) ) ** 2) * torch.tensor(variance_mask))

# %%
variance_mask = np.nanvar(attenu_fromEm_standard[:, 0, :, :], axis = 0)

# %%
plt.plot(variance_mask.flatten())

# %%
torch.autograd.set_detect_anomaly(True)

batch_size = 64
num_epochs = 4000
early_stopping_treshold = 1e-7

attenu_fromEm_dataset = TensorDataset(attenu_fromEm_standard, attenu_fromEm_standard)

train_size = (int(0.7 * len(attenu_fromEm_standard)) // 4) * 4
val_size = int((len(attenu_fromEm_standard) - train_size)/2)
test_size = int(len(attenu_fromEm_standard) - train_size - val_size)

generator = torch.Generator().manual_seed(42)
attenu_fromEm_train_dataset, attenu_fromEm_val_dataset, attenu_fromEm_test_dataset = random_split(attenu_fromEm_dataset, [train_size, val_size, test_size], generator=generator)

attenu_fromEm_train_dataloader = DataLoader(attenu_fromEm_train_dataset, batch_size = batch_size, shuffle = 1)
attenu_fromEm_val_dataloader = DataLoader(attenu_fromEm_val_dataset, batch_size = batch_size, shuffle = 1)
attenu_fromEm_test_dataloader = DataLoader(attenu_fromEm_test_dataset, batch_size = batch_size, shuffle = 1)

model = Autoencoder(image_dimension = attenu_fromEm_standard.shape[2])
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
criterion = nn.MSELoss()




epoch_loss = []
epoch_loss_val = []

# using linear regression to prevent overfitting
window_size = 100

reg = sklearn.linear_model.LinearRegression()
window = np.arange(window_size).reshape(-1, 1)

try:
    for epoch in range(num_epochs):
        start = torch.Event(enable_timing=True)
        end = torch.Event(enable_timing=True)

        start.record()

        model.train()
        running_loss = 0.0
        running_loss_val = 0.0
        for train_batch, _ in attenu_fromEm_train_dataloader:
            
            outputs = model.main(train_batch)
            loss = criterion(outputs, train_batch)
            #loss = flightpath_MSELoss(outputs, train_batch, radar_mask)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * train_batch.size(0)
        
        for val_batch, _ in attenu_fromEm_val_dataloader:
            outputs = model.main(val_batch)
            loss = criterion(outputs, val_batch)
            #loss = flightpath_MSELoss(outputs, val_batch, radar_mask)

            running_loss_val += loss.item() * val_batch.size(0)
        
        epoch_loss.append(running_loss / len(attenu_fromEm_train_dataloader.dataset))
        epoch_loss_val.append(running_loss_val / len(attenu_fromEm_val_dataloader.dataset))

        end.record()

        print(f"Epoch [{epoch + 1}/{num_epochs}], loss: {epoch_loss[epoch]:.4f}, validation loss: {epoch_loss_val[epoch]:.4f}, time elapsed = {start.elapsed_time(end)/1000:.2f} s")
        
        

        if epoch >= window.shape[0]:
            reg.fit(window, epoch_loss[-window_size:])
            epoch_loss_slope = reg.coef_
            print(f"Epoch loss slope: {epoch_loss_slope}")

            reg.fit(window, epoch_loss_val[-window_size:])
            epoch_loss_val_slope = reg.coef_
            print(f"Epoch validation loss slope: {epoch_loss_val_slope}")

            # if (np.abs(epoch_loss_slope) < early_stopping_treshold) or (np.abs(epoch_loss_val_slope) < early_stopping_treshold):
            #     print("Early stopping")
            #     break
        
    torch.save(model.state_dict(), f'autoencoder_{datetime.datetime.now()}.pth')
    np.savez(f'autoencoder_{datetime.datetime.now()}_loss.npz',epoch_loss = epoch_loss, epoch_loss_val = epoch_loss_val)

except KeyboardInterrupt:
    torch.save(model.state_dict(), f'autoencoder_{datetime.datetime.now()}.pth')
    np.savez(f'autoencoder_{datetime.datetime.now()}_loss.npz',epoch_loss = epoch_loss, epoch_loss_val = epoch_loss_val)
# Out:
# Epoch [1/4000], loss: 0.0794, validation loss: 0.0580, time elapsed = 0.37 s
# Epoch [2/4000], loss: 0.0548, validation loss: 0.0466, time elapsed = 0.37 s
# Epoch [3/4000], loss: 0.0447, validation loss: 0.0408, time elapsed = 0.37 s
# Epoch [4/4000], loss: 0.0398, validation loss: 0.0391, time elapsed = 0.36 s
# Epoch [5/4000], loss: 0.0385, validation loss: 0.0388, time elapsed = 0.35 s
# Epoch [6/4000], loss: 0.0381, validation loss: 0.0382, time elapsed = 0.36 s
# Epoch [7/4000], loss: 0.0375, validation loss: 0.0374, time elapsed = 0.35 s
# Epoch [8/4000], loss: 0.0366, validation loss: 0.0367, time elapsed = 0.35 s
# Epoch [9/4000], loss: 0.0360, validation loss: 0.0361, time elapsed = 0.35 s
# Epoch [10/4000], loss: 0.0354, validation loss: 0.0356, time elapsed = 0.35 s
# Epoch [11/4000], loss: 0.0350, validation loss: 0.0352, time elapsed = 0.35 s
# Epoch [12/4000], loss: 0.0346, validation loss: 0.0349, time elapsed = 0.35 s
# Epoch [13/4000], loss: 0.0342, validation loss: 0.0346, time elapsed = 0.35 s
# Epoch [14/4000], loss: 0.0339, validation loss: 0.0343, time elapsed = 0.35 s
# Epoch [15/4000], loss: 0.0336, validation loss: 0.0340, time elapsed = 0.35 s
# Epoch [16/4000], loss: 0.0333, validation loss: 0.0337, time elapsed = 0.36 s
# Epoch [17/4000], loss: 0.0330, validation loss: 0.0334, time elapsed = 0.35 s
# Epoch [18/4000], loss: 0.0327, validation loss: 0.0331, time elapsed = 0.35 s
# Epoch [19/4000], loss: 0.0324, validation loss: 0.0328, time elapsed = 0.36 s
# Epoch [20/4000], loss: 0.0321, validation loss: 0.0325, time elapsed = 0.36 s
# Epoch [21/4000], loss: 0.0318, validation loss: 0.0321, time elapsed = 0.35 s
# Epoch [22/4000], loss: 0.0315, validation loss: 0.0319, time elapsed = 0.36 s
# Epoch [23/4000], loss: 0.0312, validation loss: 0.0316, time elapsed = 0.39 s
# Epoch [24/4000], loss: 0.0309, validation loss: 0.0313, time elapsed = 0.36 s
# Epoch [25/4000], loss: 0.0306, validation loss: 0.0310, time elapsed = 0.36 s
# Epoch [26/4000], loss: 0.0303, validation loss: 0.0307, time elapsed = 0.36 s
# Epoch [27/4000], loss: 0.0300, validation loss: 0.0304, time elapsed = 0.36 s
# Epoch [28/4000], loss: 0.0297, validation loss: 0.0301, time elapsed = 0.37 s
# Epoch [29/4000], loss: 0.0294, validation loss: 0.0297, time elapsed = 0.37 s
# Epoch [30/4000], loss: 0.0291, validation loss: 0.0294, time elapsed = 0.36 s
# Epoch [31/4000], loss: 0.0288, validation loss: 0.0291, time elapsed = 0.36 s
# Epoch [32/4000], loss: 0.0284, validation loss: 0.0288, time elapsed = 0.36 s
# Epoch [33/4000], loss: 0.0281, validation loss: 0.0285, time elapsed = 0.36 s
# Epoch [34/4000], loss: 0.0278, validation loss: 0.0282, time elapsed = 0.35 s
# Epoch [35/4000], loss: 0.0275, validation loss: 0.0279, time elapsed = 0.35 s
# Epoch [36/4000], loss: 0.0272, validation loss: 0.0276, time elapsed = 0.36 s
# Epoch [37/4000], loss: 0.0269, validation loss: 0.0273, time elapsed = 0.37 s
# Epoch [38/4000], loss: 0.0266, validation loss: 0.0270, time elapsed = 0.36 s
# Epoch [39/4000], loss: 0.0263, validation loss: 0.0267, time elapsed = 0.36 s
# Epoch [40/4000], loss: 0.0260, validation loss: 0.0265, time elapsed = 0.36 s
# Epoch [41/4000], loss: 0.0257, validation loss: 0.0262, time elapsed = 0.36 s
# Epoch [42/4000], loss: 0.0255, validation loss: 0.0259, time elapsed = 0.36 s
# Epoch [43/4000], loss: 0.0252, validation loss: 0.0256, time elapsed = 0.36 s
# Epoch [44/4000], loss: 0.0249, validation loss: 0.0253, time elapsed = 0.36 s
# Epoch [45/4000], loss: 0.0246, validation loss: 0.0250, time elapsed = 0.36 s
# Epoch [46/4000], loss: 0.0243, validation loss: 0.0247, time elapsed = 0.36 s
# Epoch [47/4000], loss: 0.0240, validation loss: 0.0244, time elapsed = 0.36 s
# Epoch [48/4000], loss: 0.0236, validation loss: 0.0240, time elapsed = 0.36 s
# Epoch [49/4000], loss: 0.0233, validation loss: 0.0236, time elapsed = 0.36 s
# Epoch [50/4000], loss: 0.0229, validation loss: 0.0233, time elapsed = 0.36 s
# Epoch [51/4000], loss: 0.0226, validation loss: 0.0229, time elapsed = 0.35 s
# Epoch [52/4000], loss: 0.0222, validation loss: 0.0225, time elapsed = 0.36 s
# Epoch [53/4000], loss: 0.0218, validation loss: 0.0222, time elapsed = 0.37 s
# Epoch [54/4000], loss: 0.0214, validation loss: 0.0218, time elapsed = 0.38 s
# Epoch [55/4000], loss: 0.0210, validation loss: 0.0214, time elapsed = 0.37 s
# Epoch [56/4000], loss: 0.0207, validation loss: 0.0210, time elapsed = 0.37 s
# Epoch [57/4000], loss: 0.0203, validation loss: 0.0207, time elapsed = 0.37 s
# Epoch [58/4000], loss: 0.0199, validation loss: 0.0203, time elapsed = 0.37 s
# Epoch [59/4000], loss: 0.0196, validation loss: 0.0200, time elapsed = 0.37 s
# Epoch [60/4000], loss: 0.0192, validation loss: 0.0196, time elapsed = 0.42 s
# Epoch [61/4000], loss: 0.0189, validation loss: 0.0193, time elapsed = 0.37 s
# Epoch [62/4000], loss: 0.0186, validation loss: 0.0190, time elapsed = 0.37 s
# Epoch [63/4000], loss: 0.0183, validation loss: 0.0187, time elapsed = 0.36 s
# Epoch [64/4000], loss: 0.0180, validation loss: 0.0184, time elapsed = 0.36 s
# Epoch [65/4000], loss: 0.0177, validation loss: 0.0181, time elapsed = 0.36 s
# Epoch [66/4000], loss: 0.0174, validation loss: 0.0178, time elapsed = 0.39 s
# Epoch [67/4000], loss: 0.0171, validation loss: 0.0176, time elapsed = 0.37 s
# Epoch [68/4000], loss: 0.0169, validation loss: 0.0173, time elapsed = 0.41 s
# Epoch [69/4000], loss: 0.0166, validation loss: 0.0171, time elapsed = 0.38 s
# Epoch [70/4000], loss: 0.0164, validation loss: 0.0169, time elapsed = 0.36 s
# Epoch [71/4000], loss: 0.0162, validation loss: 0.0167, time elapsed = 0.37 s
# Epoch [72/4000], loss: 0.0160, validation loss: 0.0165, time elapsed = 0.36 s
# Epoch [73/4000], loss: 0.0158, validation loss: 0.0164, time elapsed = 0.36 s
# Epoch [74/4000], loss: 0.0156, validation loss: 0.0162, time elapsed = 0.36 s
# Epoch [75/4000], loss: 0.0154, validation loss: 0.0160, time elapsed = 0.36 s
# Epoch [76/4000], loss: 0.0153, validation loss: 0.0158, time elapsed = 0.36 s
# Epoch [77/4000], loss: 0.0151, validation loss: 0.0157, time elapsed = 0.36 s
# Epoch [78/4000], loss: 0.0150, validation loss: 0.0156, time elapsed = 0.36 s
# Epoch [79/4000], loss: 0.0149, validation loss: 0.0154, time elapsed = 0.36 s
# Epoch [80/4000], loss: 0.0147, validation loss: 0.0154, time elapsed = 0.36 s
# Epoch [81/4000], loss: 0.0147, validation loss: 0.0152, time elapsed = 0.36 s
# Epoch [82/4000], loss: 0.0145, validation loss: 0.0151, time elapsed = 0.36 s
# Epoch [83/4000], loss: 0.0144, validation loss: 0.0151, time elapsed = 0.36 s
# Epoch [84/4000], loss: 0.0143, validation loss: 0.0150, time elapsed = 0.36 s
# Epoch [85/4000], loss: 0.0142, validation loss: 0.0149, time elapsed = 0.36 s
# Epoch [86/4000], loss: 0.0141, validation loss: 0.0148, time elapsed = 0.36 s
# Epoch [87/4000], loss: 0.0140, validation loss: 0.0147, time elapsed = 0.37 s
# Epoch [88/4000], loss: 0.0140, validation loss: 0.0146, time elapsed = 0.36 s
# Epoch [89/4000], loss: 0.0139, validation loss: 0.0145, time elapsed = 0.36 s
# Epoch [90/4000], loss: 0.0138, validation loss: 0.0145, time elapsed = 0.36 s
# Epoch [91/4000], loss: 0.0138, validation loss: 0.0144, time elapsed = 0.36 s
# Epoch [92/4000], loss: 0.0137, validation loss: 0.0144, time elapsed = 0.36 s
# Epoch [93/4000], loss: 0.0136, validation loss: 0.0143, time elapsed = 0.36 s
# Epoch [94/4000], loss: 0.0136, validation loss: 0.0142, time elapsed = 0.38 s
# Epoch [95/4000], loss: 0.0135, validation loss: 0.0142, time elapsed = 0.38 s
# Epoch [96/4000], loss: 0.0135, validation loss: 0.0142, time elapsed = 0.38 s
# Epoch [97/4000], loss: 0.0134, validation loss: 0.0140, time elapsed = 0.40 s
# Epoch [98/4000], loss: 0.0133, validation loss: 0.0140, time elapsed = 0.37 s
# Epoch [99/4000], loss: 0.0133, validation loss: 0.0140, time elapsed = 0.36 s
# Epoch [100/4000], loss: 0.0132, validation loss: 0.0138, time elapsed = 0.37 s
# Epoch [101/4000], loss: 0.0132, validation loss: 0.0138, time elapsed = 0.37 s
# Epoch loss slope: [-0.0002897]
# Epoch validation loss slope: [-0.00027724]
# Epoch [102/4000], loss: 0.0131, validation loss: 0.0138, time elapsed = 0.39 s
# Epoch loss slope: [-0.00027688]
# Epoch validation loss slope: [-0.00026938]
# Epoch [103/4000], loss: 0.0131, validation loss: 0.0137, time elapsed = 0.36 s
# Epoch loss slope: [-0.00026972]
# Epoch validation loss slope: [-0.00026466]
# Epoch [104/4000], loss: 0.0130, validation loss: 0.0138, time elapsed = 0.36 s
# Epoch loss slope: [-0.00026518]
# Epoch validation loss slope: [-0.00026059]
# Epoch [105/4000], loss: 0.0130, validation loss: 0.0138, time elapsed = 0.37 s
# Epoch loss slope: [-0.0002611]
# Epoch validation loss slope: [-0.00025638]
# Epoch [106/4000], loss: 0.0129, validation loss: 0.0136, time elapsed = 0.38 s
# Epoch loss slope: [-0.00025697]
# Epoch validation loss slope: [-0.00025235]
# Epoch [107/4000], loss: 0.0129, validation loss: 0.0136, time elapsed = 0.37 s
# Epoch loss slope: [-0.00025295]
# Epoch validation loss slope: [-0.00024855]
# Epoch [108/4000], loss: 0.0129, validation loss: 0.0136, time elapsed = 0.36 s
# Epoch loss slope: [-0.00024914]
# Epoch validation loss slope: [-0.00024487]
# Epoch [109/4000], loss: 0.0128, validation loss: 0.0134, time elapsed = 0.36 s
# Epoch loss slope: [-0.00024548]
# Epoch validation loss slope: [-0.00024135]
# Epoch [110/4000], loss: 0.0128, validation loss: 0.0135, time elapsed = 0.36 s
# Epoch loss slope: [-0.00024193]
# Epoch validation loss slope: [-0.00023781]
# Epoch [111/4000], loss: 0.0127, validation loss: 0.0135, time elapsed = 0.36 s
# Epoch loss slope: [-0.00023838]
# Epoch validation loss slope: [-0.00023424]
# Epoch [112/4000], loss: 0.0127, validation loss: 0.0134, time elapsed = 0.36 s
# Epoch loss slope: [-0.00023482]
# Epoch validation loss slope: [-0.00023071]
# Epoch [113/4000], loss: 0.0127, validation loss: 0.0133, time elapsed = 0.36 s
# Epoch loss slope: [-0.00023126]
# Epoch validation loss slope: [-0.00022714]
# Epoch [114/4000], loss: 0.0126, validation loss: 0.0134, time elapsed = 0.36 s
# Epoch loss slope: [-0.00022765]
# Epoch validation loss slope: [-0.00022346]
# Epoch [115/4000], loss: 0.0126, validation loss: 0.0133, time elapsed = 0.36 s
# Epoch loss slope: [-0.00022397]
# Epoch validation loss slope: [-0.00021974]
# Epoch [116/4000], loss: 0.0126, validation loss: 0.0131, time elapsed = 0.36 s
# Epoch loss slope: [-0.00022024]
# Epoch validation loss slope: [-0.00021606]
# Epoch [117/4000], loss: 0.0125, validation loss: 0.0132, time elapsed = 0.36 s
# Epoch loss slope: [-0.00021649]
# Epoch validation loss slope: [-0.0002123]
# Epoch [118/4000], loss: 0.0124, validation loss: 0.0131, time elapsed = 0.36 s
# Epoch loss slope: [-0.00021272]
# Epoch validation loss slope: [-0.00020849]
# Epoch [119/4000], loss: 0.0124, validation loss: 0.0131, time elapsed = 0.36 s
# Epoch loss slope: [-0.0002089]
# Epoch validation loss slope: [-0.00020466]
# Epoch [120/4000], loss: 0.0123, validation loss: 0.0130, time elapsed = 0.36 s
# Epoch loss slope: [-0.00020505]
# Epoch validation loss slope: [-0.00020084]
# Epoch [121/4000], loss: 0.0123, validation loss: 0.0130, time elapsed = 0.36 s
# Epoch loss slope: [-0.0002012]
# Epoch validation loss slope: [-0.00019697]
# Epoch [122/4000], loss: 0.0123, validation loss: 0.0131, time elapsed = 0.36 s
# Epoch loss slope: [-0.00019731]
# Epoch validation loss slope: [-0.00019302]
# Epoch [123/4000], loss: 0.0123, validation loss: 0.0129, time elapsed = 0.36 s
# Epoch loss slope: [-0.00019338]
# Epoch validation loss slope: [-0.00018911]
# Epoch [124/4000], loss: 0.0122, validation loss: 0.0128, time elapsed = 0.36 s
# Epoch loss slope: [-0.00018942]
# Epoch validation loss slope: [-0.00018517]
# Epoch [125/4000], loss: 0.0122, validation loss: 0.0128, time elapsed = 0.36 s
# Epoch loss slope: [-0.00018543]
# Epoch validation loss slope: [-0.00018117]
# Epoch [126/4000], loss: 0.0121, validation loss: 0.0128, time elapsed = 0.36 s
# Epoch loss slope: [-0.00018142]
# Epoch validation loss slope: [-0.00017718]
# Epoch [127/4000], loss: 0.0121, validation loss: 0.0127, time elapsed = 0.36 s
# Epoch loss slope: [-0.00017742]
# Epoch validation loss slope: [-0.00017322]
# Epoch [128/4000], loss: 0.0120, validation loss: 0.0127, time elapsed = 0.36 s
# Epoch loss slope: [-0.00017343]
# Epoch validation loss slope: [-0.00016922]
# Epoch [129/4000], loss: 0.0120, validation loss: 0.0127, time elapsed = 0.36 s
# Epoch loss slope: [-0.00016943]
# Epoch validation loss slope: [-0.00016524]
# Epoch [130/4000], loss: 0.0119, validation loss: 0.0126, time elapsed = 0.36 s
# Epoch loss slope: [-0.00016545]
# Epoch validation loss slope: [-0.00016131]
# Epoch [131/4000], loss: 0.0119, validation loss: 0.0125, time elapsed = 0.36 s
# Epoch loss slope: [-0.00016147]
# Epoch validation loss slope: [-0.00015739]
# Epoch [132/4000], loss: 0.0119, validation loss: 0.0126, time elapsed = 0.36 s
# Epoch loss slope: [-0.00015747]
# Epoch validation loss slope: [-0.00015347]
# Epoch [133/4000], loss: 0.0118, validation loss: 0.0125, time elapsed = 0.36 s
# Epoch loss slope: [-0.00015354]
# Epoch validation loss slope: [-0.00014957]
# Epoch [134/4000], loss: 0.0118, validation loss: 0.0124, time elapsed = 0.36 s
# Epoch loss slope: [-0.00014961]
# Epoch validation loss slope: [-0.00014569]
# Epoch [135/4000], loss: 0.0118, validation loss: 0.0124, time elapsed = 0.36 s
# Epoch loss slope: [-0.0001457]
# Epoch validation loss slope: [-0.00014181]
# Epoch [136/4000], loss: 0.0117, validation loss: 0.0124, time elapsed = 0.36 s
# Epoch loss slope: [-0.00014179]
# Epoch validation loss slope: [-0.00013793]
# Epoch [137/4000], loss: 0.0117, validation loss: 0.0124, time elapsed = 0.37 s
# Epoch loss slope: [-0.00013787]
# Epoch validation loss slope: [-0.00013402]
# Epoch [138/4000], loss: 0.0117, validation loss: 0.0123, time elapsed = 0.36 s
# Epoch loss slope: [-0.00013397]
# Epoch validation loss slope: [-0.00013017]
# Epoch [139/4000], loss: 0.0117, validation loss: 0.0123, time elapsed = 0.36 s
# Epoch loss slope: [-0.00013009]
# Epoch validation loss slope: [-0.00012637]
# Epoch [140/4000], loss: 0.0116, validation loss: 0.0122, time elapsed = 0.36 s
# Epoch loss slope: [-0.00012622]
# Epoch validation loss slope: [-0.00012258]
# Epoch [141/4000], loss: 0.0115, validation loss: 0.0122, time elapsed = 0.36 s
# Epoch loss slope: [-0.00012241]
# Epoch validation loss slope: [-0.00011879]
# Epoch [142/4000], loss: 0.0115, validation loss: 0.0122, time elapsed = 0.36 s
# Epoch loss slope: [-0.00011863]
# Epoch validation loss slope: [-0.00011503]
# Epoch [143/4000], loss: 0.0115, validation loss: 0.0121, time elapsed = 0.36 s
# Epoch loss slope: [-0.00011488]
# Epoch validation loss slope: [-0.00011133]
# Epoch [144/4000], loss: 0.0114, validation loss: 0.0121, time elapsed = 0.36 s
# Epoch loss slope: [-0.00011115]
# Epoch validation loss slope: [-0.00010765]
# Epoch [145/4000], loss: 0.0114, validation loss: 0.0121, time elapsed = 0.36 s
# Epoch loss slope: [-0.00010748]
# Epoch validation loss slope: [-0.000104]
# Epoch [146/4000], loss: 0.0114, validation loss: 0.0120, time elapsed = 0.36 s
# Epoch loss slope: [-0.00010384]
# Epoch validation loss slope: [-0.00010042]
# Epoch [147/4000], loss: 0.0113, validation loss: 0.0120, time elapsed = 0.36 s
# Epoch loss slope: [-0.00010025]
# Epoch validation loss slope: [-9.68749791e-05]
# Epoch [148/4000], loss: 0.0113, validation loss: 0.0119, time elapsed = 0.36 s
# Epoch loss slope: [-9.673287e-05]
# Epoch validation loss slope: [-9.34541111e-05]
# Epoch [149/4000], loss: 0.0113, validation loss: 0.0120, time elapsed = 0.36 s
# Epoch loss slope: [-9.32971753e-05]
# Epoch validation loss slope: [-9.00742647e-05]
# Epoch [150/4000], loss: 0.0113, validation loss: 0.0120, time elapsed = 0.36 s
# Epoch loss slope: [-8.99166359e-05]
# Epoch validation loss slope: [-8.6816146e-05]
# Epoch [151/4000], loss: 0.0113, validation loss: 0.0119, time elapsed = 0.36 s
# Epoch loss slope: [-8.66247273e-05]
# Epoch validation loss slope: [-8.36925152e-05]
# Epoch [152/4000], loss: 0.0112, validation loss: 0.0119, time elapsed = 0.37 s
# Epoch loss slope: [-8.34852143e-05]
# Epoch validation loss slope: [-8.06834142e-05]
# Epoch [153/4000], loss: 0.0111, validation loss: 0.0118, time elapsed = 0.36 s
# Epoch loss slope: [-8.04718548e-05]
# Epoch validation loss slope: [-7.77634668e-05]
# Epoch [154/4000], loss: 0.0111, validation loss: 0.0119, time elapsed = 0.36 s
# Epoch loss slope: [-7.75710867e-05]
# Epoch validation loss slope: [-7.49452969e-05]
# Epoch [155/4000], loss: 0.0111, validation loss: 0.0117, time elapsed = 0.36 s
# Epoch loss slope: [-7.48166302e-05]
# Epoch validation loss slope: [-7.23104783e-05]
# Epoch [156/4000], loss: 0.0110, validation loss: 0.0117, time elapsed = 0.36 s
# Epoch loss slope: [-7.21746857e-05]
# Epoch validation loss slope: [-6.98055494e-05]
# Epoch [157/4000], loss: 0.0110, validation loss: 0.0118, time elapsed = 0.37 s
# Epoch loss slope: [-6.96679474e-05]
# Epoch validation loss slope: [-6.73735477e-05]
# Epoch [158/4000], loss: 0.0110, validation loss: 0.0118, time elapsed = 0.36 s
# Epoch loss slope: [-6.72686235e-05]
# Epoch validation loss slope: [-6.50724386e-05]
# Epoch [159/4000], loss: 0.0110, validation loss: 0.0117, time elapsed = 0.36 s
# Epoch loss slope: [-6.49929214e-05]
# Epoch validation loss slope: [-6.29147802e-05]
# Epoch [160/4000], loss: 0.0109, validation loss: 0.0116, time elapsed = 0.36 s
# Epoch loss slope: [-6.28388648e-05]
# Epoch validation loss slope: [-6.08751356e-05]
# Epoch [161/4000], loss: 0.0109, validation loss: 0.0116, time elapsed = 0.36 s
# Epoch loss slope: [-6.07889689e-05]
# Epoch validation loss slope: [-5.89710632e-05]
# Epoch [162/4000], loss: 0.0109, validation loss: 0.0116, time elapsed = 0.36 s
# Epoch loss slope: [-5.88495474e-05]
# Epoch validation loss slope: [-5.71468809e-05]
# Epoch [163/4000], loss: 0.0109, validation loss: 0.0117, time elapsed = 0.36 s
# Epoch loss slope: [-5.70144169e-05]
# Epoch validation loss slope: [-5.53571308e-05]
# Epoch [164/4000], loss: 0.0109, validation loss: 0.0116, time elapsed = 0.36 s
# Epoch loss slope: [-5.52932701e-05]
# Epoch validation loss slope: [-5.37399471e-05]
# Epoch [165/4000], loss: 0.0108, validation loss: 0.0115, time elapsed = 0.36 s
# Epoch loss slope: [-5.36944959e-05]
# Epoch validation loss slope: [-5.22203785e-05]
# Epoch [166/4000], loss: 0.0108, validation loss: 0.0115, time elapsed = 0.36 s
# Epoch loss slope: [-5.21731104e-05]
# Epoch validation loss slope: [-5.0843576e-05]
# Epoch [167/4000], loss: 0.0108, validation loss: 0.0114, time elapsed = 0.37 s
# Epoch loss slope: [-5.07923496e-05]
# Epoch validation loss slope: [-4.95707338e-05]
# Epoch [168/4000], loss: 0.0108, validation loss: 0.0114, time elapsed = 0.36 s
# Epoch loss slope: [-4.94839076e-05]
# Epoch validation loss slope: [-4.84042165e-05]
# Epoch [169/4000], loss: 0.0107, validation loss: 0.0114, time elapsed = 0.36 s
# Epoch loss slope: [-4.82746207e-05]
# Epoch validation loss slope: [-4.72841345e-05]
# Epoch [170/4000], loss: 0.0107, validation loss: 0.0113, time elapsed = 0.36 s
# Epoch loss slope: [-4.71508602e-05]
# Epoch validation loss slope: [-4.62560925e-05]
# Epoch [171/4000], loss: 0.0107, validation loss: 0.0114, time elapsed = 0.36 s
# Epoch loss slope: [-4.61181781e-05]
# Epoch validation loss slope: [-4.52907668e-05]
# Epoch [172/4000], loss: 0.0106, validation loss: 0.0114, time elapsed = 0.36 s
# Epoch loss slope: [-4.51653343e-05]
# Epoch validation loss slope: [-4.43694157e-05]
# Epoch [173/4000], loss: 0.0107, validation loss: 0.0113, time elapsed = 0.36 s
# Epoch loss slope: [-4.42193521e-05]
# Epoch validation loss slope: [-4.35078149e-05]
# Epoch [174/4000], loss: 0.0106, validation loss: 0.0114, time elapsed = 0.36 s
# Epoch loss slope: [-4.33626275e-05]
# Epoch validation loss slope: [-4.26390023e-05]
# Epoch [175/4000], loss: 0.0107, validation loss: 0.0113, time elapsed = 0.38 s
# Epoch loss slope: [-4.25305948e-05]
# Epoch validation loss slope: [-4.18800488e-05]
# Epoch [176/4000], loss: 0.0106, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-4.17542451e-05]
# Epoch validation loss slope: [-4.11935637e-05]
# Epoch [177/4000], loss: 0.0106, validation loss: 0.0113, time elapsed = 0.36 s
# Epoch loss slope: [-4.10454253e-05]
# Epoch validation loss slope: [-4.04780619e-05]
# Epoch [178/4000], loss: 0.0106, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-4.03722645e-05]
# Epoch validation loss slope: [-3.98654949e-05]
# Epoch [179/4000], loss: 0.0105, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-3.97186508e-05]
# Epoch validation loss slope: [-3.9302234e-05]
# Epoch [180/4000], loss: 0.0105, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-3.91431933e-05]
# Epoch validation loss slope: [-3.86541354e-05]
# Epoch [181/4000], loss: 0.0105, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-3.85289519e-05]
# Epoch validation loss slope: [-3.80961289e-05]
# Epoch [182/4000], loss: 0.0104, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.79937515e-05]
# Epoch validation loss slope: [-3.76054222e-05]
# Epoch [183/4000], loss: 0.0104, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.74791923e-05]
# Epoch validation loss slope: [-3.71356615e-05]
# Epoch [184/4000], loss: 0.0105, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.69485618e-05]
# Epoch validation loss slope: [-3.66451317e-05]
# Epoch [185/4000], loss: 0.0104, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-3.64489325e-05]
# Epoch validation loss slope: [-3.61211161e-05]
# Epoch [186/4000], loss: 0.0104, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.59852473e-05]
# Epoch validation loss slope: [-3.56807181e-05]
# Epoch [187/4000], loss: 0.0104, validation loss: 0.0111, time elapsed = 0.39 s
# Epoch loss slope: [-3.55394902e-05]
# Epoch validation loss slope: [-3.52592225e-05]
# Epoch [188/4000], loss: 0.0104, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.5107746e-05]
# Epoch validation loss slope: [-3.4817614e-05]
# Epoch [189/4000], loss: 0.0104, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.4682028e-05]
# Epoch validation loss slope: [-3.44045323e-05]
# Epoch [190/4000], loss: 0.0103, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.42746453e-05]
# Epoch validation loss slope: [-3.39774925e-05]
# Epoch [191/4000], loss: 0.0103, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.38437089e-05]
# Epoch validation loss slope: [-3.35440452e-05]
# Epoch [192/4000], loss: 0.0103, validation loss: 0.0110, time elapsed = 0.36 s
# Epoch loss slope: [-3.34279126e-05]
# Epoch validation loss slope: [-3.31586337e-05]
# Epoch [193/4000], loss: 0.0103, validation loss: 0.0110, time elapsed = 0.36 s
# Epoch loss slope: [-3.30262829e-05]
# Epoch validation loss slope: [-3.27845842e-05]
# Epoch [194/4000], loss: 0.0103, validation loss: 0.0111, time elapsed = 0.36 s
# Epoch loss slope: [-3.26011594e-05]
# Epoch validation loss slope: [-3.2365732e-05]
# Epoch [195/4000], loss: 0.0103, validation loss: 0.0110, time elapsed = 0.36 s
# Epoch loss slope: [-3.22260833e-05]
# Epoch validation loss slope: [-3.19682952e-05]
# Epoch [196/4000], loss: 0.0103, validation loss: 0.0110, time elapsed = 0.36 s
# Epoch loss slope: [-3.1807785e-05]
# Epoch validation loss slope: [-3.15498942e-05]
# Epoch [197/4000], loss: 0.0102, validation loss: 0.0112, time elapsed = 0.36 s
# Epoch loss slope: [-3.14359229e-05]
# Epoch validation loss slope: [-3.10414711e-05]
# Epoch [198/4000], loss: 0.0104, validation loss: 0.0109, time elapsed = 0.36 s
# Epoch loss slope: [-3.0988784e-05]
# Epoch validation loss slope: [-3.06744547e-05]
# Epoch [199/4000], loss: 0.0103, validation loss: 0.0109, time elapsed = 0.40 s
# Epoch loss slope: [-3.05908449e-05]
# Epoch validation loss slope: [-3.02909714e-05]
# Epoch [200/4000], loss: 0.0103, validation loss: 0.0110, time elapsed = 0.39 s
# Epoch loss slope: [-3.02070351e-05]
# Epoch validation loss slope: [-2.98962199e-05]
# Epoch [201/4000], loss: 0.0102, validation loss: 0.0110, time elapsed = 0.38 s
# Epoch loss slope: [-2.98246504e-05]
# Epoch validation loss slope: [-2.95220572e-05]
# Epoch [202/4000], loss: 0.0102, validation loss: 0.0109, time elapsed = 0.38 s
# Epoch loss slope: [-2.94565944e-05]
# Epoch validation loss slope: [-2.91996374e-05]
# Epoch [203/4000], loss: 0.0102, validation loss: 0.0108, time elapsed = 0.38 s
# Epoch loss slope: [-2.90984776e-05]
# Epoch validation loss slope: [-2.88935253e-05]
# Epoch [204/4000], loss: 0.0101, validation loss: 0.0109, time elapsed = 0.38 s
# Epoch loss slope: [-2.87720417e-05]
# Epoch validation loss slope: [-2.84582632e-05]
# Epoch [205/4000], loss: 0.0101, validation loss: 0.0109, time elapsed = 0.38 s
# Epoch loss slope: [-2.84094791e-05]
# Epoch validation loss slope: [-2.80200991e-05]
# Epoch [206/4000], loss: 0.0101, validation loss: 0.0108, time elapsed = 0.38 s
# Epoch loss slope: [-2.80683386e-05]
# Epoch validation loss slope: [-2.77306004e-05]
# Epoch [207/4000], loss: 0.0101, validation loss: 0.0108, time elapsed = 0.38 s
# Epoch loss slope: [-2.77127175e-05]
# Epoch validation loss slope: [-2.74057085e-05]
# Epoch [208/4000], loss: 0.0101, validation loss: 0.0108, time elapsed = 0.44 s
# Epoch loss slope: [-2.73291071e-05]
# Epoch validation loss slope: [-2.70128969e-05]
# Epoch [209/4000], loss: 0.0101, validation loss: 0.0108, time elapsed = 0.40 s
# Epoch loss slope: [-2.69718055e-05]
# Epoch validation loss slope: [-2.66719774e-05]
# Epoch [210/4000], loss: 0.0101, validation loss: 0.0107, time elapsed = 0.39 s
# Epoch loss slope: [-2.66405483e-05]
# Epoch validation loss slope: [-2.63095001e-05]
# Epoch [211/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.38 s
# Epoch loss slope: [-2.63036555e-05]
# Epoch validation loss slope: [-2.59184104e-05]
# Epoch [212/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.38 s
# Epoch loss slope: [-2.5951394e-05]
# Epoch validation loss slope: [-2.55815553e-05]
# Epoch [213/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.38 s
# Epoch loss slope: [-2.56233303e-05]
# Epoch validation loss slope: [-2.52441124e-05]
# Epoch [214/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.38 s
# Epoch loss slope: [-2.52813279e-05]
# Epoch validation loss slope: [-2.48266368e-05]
# Epoch [215/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.38 s
# Epoch loss slope: [-2.49313553e-05]
# Epoch validation loss slope: [-2.44397304e-05]
# Epoch [216/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.39 s
# Epoch loss slope: [-2.45709668e-05]
# Epoch validation loss slope: [-2.41297336e-05]
# Epoch [217/4000], loss: 0.0099, validation loss: 0.0106, time elapsed = 0.38 s
# Epoch loss slope: [-2.42451513e-05]
# Epoch validation loss slope: [-2.38022309e-05]
# Epoch [218/4000], loss: 0.0100, validation loss: 0.0107, time elapsed = 0.38 s
# Epoch loss slope: [-2.39213756e-05]
# Epoch validation loss slope: [-2.34341013e-05]
# Epoch [219/4000], loss: 0.0099, validation loss: 0.0107, time elapsed = 0.39 s
# Epoch loss slope: [-2.36057034e-05]
# Epoch validation loss slope: [-2.30670891e-05]
# Epoch [220/4000], loss: 0.0099, validation loss: 0.0107, time elapsed = 0.39 s
# Epoch loss slope: [-2.32918666e-05]
# Epoch validation loss slope: [-2.27609839e-05]
# Epoch [221/4000], loss: 0.0100, validation loss: 0.0106, time elapsed = 0.39 s
# Epoch loss slope: [-2.29540114e-05]
# Epoch validation loss slope: [-2.2452576e-05]
# Epoch [222/4000], loss: 0.0099, validation loss: 0.0106, time elapsed = 0.39 s
# Epoch loss slope: [-2.26460386e-05]
# Epoch validation loss slope: [-2.20610359e-05]
# Epoch [223/4000], loss: 0.0099, validation loss: 0.0106, time elapsed = 0.39 s
# Epoch loss slope: [-2.23294217e-05]
# Epoch validation loss slope: [-2.1765687e-05]
# Epoch [224/4000], loss: 0.0099, validation loss: 0.0106, time elapsed = 0.48 s
# Epoch loss slope: [-2.20209465e-05]
# Epoch validation loss slope: [-2.14842352e-05]
# Epoch [225/4000], loss: 0.0099, validation loss: 0.0105, time elapsed = 0.42 s
# Epoch loss slope: [-2.17038076e-05]
# Epoch validation loss slope: [-2.11855893e-05]
# Epoch [226/4000], loss: 0.0098, validation loss: 0.0105, time elapsed = 0.39 s
# Epoch loss slope: [-2.14043432e-05]
# Epoch validation loss slope: [-2.09023848e-05]
# Epoch [227/4000], loss: 0.0098, validation loss: 0.0105, time elapsed = 0.38 s
# Epoch loss slope: [-2.11122381e-05]
# Epoch validation loss slope: [-2.06400338e-05]
# Epoch [228/4000], loss: 0.0098, validation loss: 0.0106, time elapsed = 0.40 s
# Epoch loss slope: [-2.08166955e-05]
# Epoch validation loss slope: [-2.03147515e-05]
# Epoch [229/4000], loss: 0.0098, validation loss: 0.0106, time elapsed = 0.38 s
# Epoch loss slope: [-2.05197354e-05]
# Epoch validation loss slope: [-1.99742449e-05]
# Epoch [230/4000], loss: 0.0098, validation loss: 0.0105, time elapsed = 0.37 s
# Epoch loss slope: [-2.02489159e-05]
# Epoch validation loss slope: [-1.9734618e-05]
# Epoch [231/4000], loss: 0.0098, validation loss: 0.0105, time elapsed = 0.39 s
# Epoch loss slope: [-1.994305e-05]
# Epoch validation loss slope: [-1.9502905e-05]
# Epoch [232/4000], loss: 0.0098, validation loss: 0.0106, time elapsed = 0.41 s
# Epoch loss slope: [-1.9638329e-05]
# Epoch validation loss slope: [-1.91554448e-05]
# Epoch [233/4000], loss: 0.0098, validation loss: 0.0105, time elapsed = 0.41 s
# Epoch loss slope: [-1.93517389e-05]
# Epoch validation loss slope: [-1.88833184e-05]
# Epoch [234/4000], loss: 0.0098, validation loss: 0.0104, time elapsed = 0.42 s
# Epoch loss slope: [-1.91021867e-05]
# Epoch validation loss slope: [-1.86769424e-05]
# Epoch [235/4000], loss: 0.0098, validation loss: 0.0104, time elapsed = 0.42 s
# Epoch loss slope: [-1.88133515e-05]
# Epoch validation loss slope: [-1.84330486e-05]
# Epoch [236/4000], loss: 0.0097, validation loss: 0.0105, time elapsed = 0.38 s
# Epoch loss slope: [-1.85490092e-05]
# Epoch validation loss slope: [-1.81471689e-05]
# Epoch [237/4000], loss: 0.0097, validation loss: 0.0105, time elapsed = 0.38 s
# Epoch loss slope: [-1.82842644e-05]
# Epoch validation loss slope: [-1.77990468e-05]
# Epoch [238/4000], loss: 0.0097, validation loss: 0.0104, time elapsed = 0.38 s
# Epoch loss slope: [-1.80154435e-05]
# Epoch validation loss slope: [-1.75634487e-05]
# Epoch [239/4000], loss: 0.0097, validation loss: 0.0104, time elapsed = 0.43 s
# Epoch loss slope: [-1.77469343e-05]
# Epoch validation loss slope: [-1.73598905e-05]
# Epoch [240/4000], loss: 0.0097, validation loss: 0.0105, time elapsed = 0.39 s
# Epoch loss slope: [-1.74726974e-05]
# Epoch validation loss slope: [-1.70963744e-05]
# Epoch [241/4000], loss: 0.0097, validation loss: 0.0105, time elapsed = 0.42 s
# Epoch loss slope: [-1.72442603e-05]
# Epoch validation loss slope: [-1.68255018e-05]
# Epoch [242/4000], loss: 0.0097, validation loss: 0.0104, time elapsed = 0.43 s
# Epoch loss slope: [-1.70180261e-05]
# Epoch validation loss slope: [-1.66106158e-05]
# Epoch [243/4000], loss: 0.0097, validation loss: 0.0105, time elapsed = 0.41 s
# Epoch loss slope: [-1.67810509e-05]
# Epoch validation loss slope: [-1.63712336e-05]
# Epoch [244/4000], loss: 0.0097, validation loss: 0.0105, time elapsed = 0.40 s
# Epoch loss slope: [-1.65644615e-05]
# Epoch validation loss slope: [-1.61048268e-05]
# Epoch [245/4000], loss: 0.0097, validation loss: 0.0103, time elapsed = 0.39 s
# Epoch loss slope: [-1.63540277e-05]
# Epoch validation loss slope: [-1.58955752e-05]
# Epoch [246/4000], loss: 0.0097, validation loss: 0.0104, time elapsed = 0.40 s
# Epoch loss slope: [-1.61440833e-05]
# Epoch validation loss slope: [-1.56871802e-05]
# Epoch [247/4000], loss: 0.0096, validation loss: 0.0104, time elapsed = 0.42 s
# Epoch loss slope: [-1.59547959e-05]
# Epoch validation loss slope: [-1.54646573e-05]
# Epoch [248/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.41 s
# Epoch loss slope: [-1.57679183e-05]
# Epoch validation loss slope: [-1.53231037e-05]
# Epoch [249/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.40 s
# Epoch loss slope: [-1.55855236e-05]
# Epoch validation loss slope: [-1.51252386e-05]
# Epoch [250/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.39 s
# Epoch loss slope: [-1.53639641e-05]
# Epoch validation loss slope: [-1.49170941e-05]
# Epoch [251/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.41 s
# Epoch loss slope: [-1.51465487e-05]
# Epoch validation loss slope: [-1.47516846e-05]
# Epoch [252/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.38 s
# Epoch loss slope: [-1.49790619e-05]
# Epoch validation loss slope: [-1.45815003e-05]
# Epoch [253/4000], loss: 0.0096, validation loss: 0.0104, time elapsed = 0.41 s
# Epoch loss slope: [-1.47846402e-05]
# Epoch validation loss slope: [-1.43658002e-05]
# Epoch [254/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.40 s
# Epoch loss slope: [-1.46311629e-05]
# Epoch validation loss slope: [-1.41625883e-05]
# Epoch [255/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.38 s
# Epoch loss slope: [-1.44730999e-05]
# Epoch validation loss slope: [-1.40385477e-05]
# Epoch [256/4000], loss: 0.0096, validation loss: 0.0103, time elapsed = 0.38 s
# Epoch loss slope: [-1.43149319e-05]
# Epoch validation loss slope: [-1.39101919e-05]
# Epoch [257/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.38 s
# Epoch loss slope: [-1.41837533e-05]
# Epoch validation loss slope: [-1.37416357e-05]
# Epoch [258/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.38 s
# Epoch loss slope: [-1.40511141e-05]
# Epoch validation loss slope: [-1.3574402e-05]
# Epoch [259/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.38 s
# Epoch loss slope: [-1.39125243e-05]
# Epoch validation loss slope: [-1.34704589e-05]
# Epoch [260/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.39 s
# Epoch loss slope: [-1.37916769e-05]
# Epoch validation loss slope: [-1.33725098e-05]
# Epoch [261/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.43 s
# Epoch loss slope: [-1.36727403e-05]
# Epoch validation loss slope: [-1.3280147e-05]
# Epoch [262/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.39 s
# Epoch loss slope: [-1.3546665e-05]
# Epoch validation loss slope: [-1.31474296e-05]
# Epoch [263/4000], loss: 0.0095, validation loss: 0.0102, time elapsed = 0.40 s
# Epoch loss slope: [-1.342592e-05]
# Epoch validation loss slope: [-1.29635089e-05]
# Epoch [264/4000], loss: 0.0094, validation loss: 0.0102, time elapsed = 0.41 s
# Epoch loss slope: [-1.33079061e-05]
# Epoch validation loss slope: [-1.28282717e-05]
# Epoch [265/4000], loss: 0.0094, validation loss: 0.0102, time elapsed = 0.41 s
# Epoch loss slope: [-1.32017628e-05]
# Epoch validation loss slope: [-1.26723213e-05]
# Epoch [266/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.44 s
# Epoch loss slope: [-1.30805021e-05]
# Epoch validation loss slope: [-1.25861393e-05]
# Epoch [267/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.51 s
# Epoch loss slope: [-1.29917432e-05]
# Epoch validation loss slope: [-1.2531166e-05]
# Epoch [268/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.44 s
# Epoch loss slope: [-1.28744788e-05]
# Epoch validation loss slope: [-1.2475366e-05]
# Epoch [269/4000], loss: 0.0094, validation loss: 0.0102, time elapsed = 0.44 s
# Epoch loss slope: [-1.27909526e-05]
# Epoch validation loss slope: [-1.23776126e-05]
# Epoch [270/4000], loss: 0.0094, validation loss: 0.0102, time elapsed = 0.49 s
# Epoch loss slope: [-1.27071091e-05]
# Epoch validation loss slope: [-1.2289512e-05]
# Epoch [271/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.43 s
# Epoch loss slope: [-1.26342937e-05]
# Epoch validation loss slope: [-1.21936237e-05]
# Epoch [272/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.50 s
# Epoch loss slope: [-1.25852333e-05]
# Epoch validation loss slope: [-1.21295421e-05]
# Epoch [273/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.44 s
# Epoch loss slope: [-1.24578429e-05]
# Epoch validation loss slope: [-1.20783388e-05]
# Epoch [274/4000], loss: 0.0094, validation loss: 0.0102, time elapsed = 0.41 s
# Epoch loss slope: [-1.23814631e-05]
# Epoch validation loss slope: [-1.18867105e-05]
# Epoch [275/4000], loss: 0.0094, validation loss: 0.0101, time elapsed = 0.49 s
# Epoch loss slope: [-1.22540868e-05]
# Epoch validation loss slope: [-1.17936551e-05]
# Epoch [276/4000], loss: 0.0093, validation loss: 0.0100, time elapsed = 0.48 s
# Epoch loss slope: [-1.21739782e-05]
# Epoch validation loss slope: [-1.17531066e-05]
# Epoch [277/4000], loss: 0.0093, validation loss: 0.0100, time elapsed = 0.41 s
# Epoch loss slope: [-1.2111607e-05]
# Epoch validation loss slope: [-1.16826121e-05]
# Epoch [278/4000], loss: 0.0093, validation loss: 0.0101, time elapsed = 0.40 s
# Epoch loss slope: [-1.20495207e-05]
# Epoch validation loss slope: [-1.16176661e-05]
# Epoch [279/4000], loss: 0.0093, validation loss: 0.0101, time elapsed = 0.39 s
# Epoch loss slope: [-1.19750696e-05]
# Epoch validation loss slope: [-1.1523106e-05]
# Epoch [280/4000], loss: 0.0093, validation loss: 0.0102, time elapsed = 0.46 s
# Epoch loss slope: [-1.19254045e-05]
# Epoch validation loss slope: [-1.13677953e-05]
# Epoch [281/4000], loss: 0.0093, validation loss: 0.0100, time elapsed = 0.49 s
# Epoch loss slope: [-1.18219267e-05]
# Epoch validation loss slope: [-1.13233954e-05]
# Epoch [282/4000], loss: 0.0093, validation loss: 0.0100, time elapsed = 0.46 s
# Epoch loss slope: [-1.17847955e-05]
# Epoch validation loss slope: [-1.13203581e-05]
# Epoch [283/4000], loss: 0.0093, validation loss: 0.0100, time elapsed = 0.52 s
# Epoch loss slope: [-1.17174166e-05]
# Epoch validation loss slope: [-1.1330061e-05]
# Epoch [284/4000], loss: 0.0093, validation loss: 0.0101, time elapsed = 0.46 s
# Epoch loss slope: [-1.16440515e-05]
# Epoch validation loss slope: [-1.12208471e-05]
# Epoch [285/4000], loss: 0.0093, validation loss: 0.0101, time elapsed = 0.50 s
# Epoch loss slope: [-1.15565752e-05]
# Epoch validation loss slope: [-1.10783709e-05]
# Epoch [286/4000], loss: 0.0093, validation loss: 0.0099, time elapsed = 0.50 s
# Epoch loss slope: [-1.15053821e-05]
# Epoch validation loss slope: [-1.10798604e-05]
# Epoch [287/4000], loss: 0.0093, validation loss: 0.0099, time elapsed = 0.47 s
# Epoch loss slope: [-1.14385629e-05]
# Epoch validation loss slope: [-1.10825242e-05]
# Epoch [288/4000], loss: 0.0093, validation loss: 0.0099, time elapsed = 0.44 s
# Epoch loss slope: [-1.13675359e-05]
# Epoch validation loss slope: [-1.10583405e-05]
# Epoch [289/4000], loss: 0.0092, validation loss: 0.0100, time elapsed = 0.42 s
# Epoch loss slope: [-1.13274858e-05]
# Epoch validation loss slope: [-1.09840385e-05]
# Epoch [290/4000], loss: 0.0092, validation loss: 0.0100, time elapsed = 0.42 s
# Epoch loss slope: [-1.12789473e-05]
# Epoch validation loss slope: [-1.08959176e-05]
# Epoch [291/4000], loss: 0.0092, validation loss: 0.0099, time elapsed = 0.42 s
# Epoch loss slope: [-1.12332532e-05]
# Epoch validation loss slope: [-1.08271486e-05]
# Epoch [292/4000], loss: 0.0092, validation loss: 0.0099, time elapsed = 0.45 s
# Epoch loss slope: [-1.11820069e-05]
# Epoch validation loss slope: [-1.08107558e-05]
# Epoch [293/4000], loss: 0.0092, validation loss: 0.0099, time elapsed = 0.48 s
# Epoch loss slope: [-1.11304111e-05]
# Epoch validation loss slope: [-1.07768609e-05]
# Epoch [294/4000], loss: 0.0092, validation loss: 0.0100, time elapsed = 0.45 s
# Epoch loss slope: [-1.10500071e-05]
# Epoch validation loss slope: [-1.06528562e-05]
# Epoch [295/4000], loss: 0.0092, validation loss: 0.0099, time elapsed = 0.51 s
# Epoch loss slope: [-1.09986721e-05]
# Epoch validation loss slope: [-1.05887516e-05]
# Epoch [296/4000], loss: 0.0092, validation loss: 0.0099, time elapsed = 0.45 s
# Epoch loss slope: [-1.09124687e-05]
# Epoch validation loss slope: [-1.05316445e-05]
# Epoch [297/4000], loss: 0.0091, validation loss: 0.0099, time elapsed = 0.41 s
# Epoch loss slope: [-1.08794345e-05]
# Epoch validation loss slope: [-1.03446188e-05]
# Epoch [298/4000], loss: 0.0091, validation loss: 0.0099, time elapsed = 0.41 s
# Epoch loss slope: [-1.07503175e-05]
# Epoch validation loss slope: [-1.02905791e-05]
# Epoch [299/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.41 s
# Epoch loss slope: [-1.06552805e-05]
# Epoch validation loss slope: [-1.02666515e-05]
# Epoch [300/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.41 s
# Epoch loss slope: [-1.05926346e-05]
# Epoch validation loss slope: [-1.01584392e-05]
# Epoch [301/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.41 s
# Epoch loss slope: [-1.05158566e-05]
# Epoch validation loss slope: [-1.00795995e-05]
# Epoch [302/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.42 s
# Epoch loss slope: [-1.0446965e-05]
# Epoch validation loss slope: [-1.0067247e-05]
# Epoch [303/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.42 s
# Epoch loss slope: [-1.04011761e-05]
# Epoch validation loss slope: [-1.00657104e-05]
# Epoch [304/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.44 s
# Epoch loss slope: [-1.03711597e-05]
# Epoch validation loss slope: [-1.00198373e-05]
# Epoch [305/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.43 s
# Epoch loss slope: [-1.03447539e-05]
# Epoch validation loss slope: [-9.94647726e-06]
# Epoch [306/4000], loss: 0.0091, validation loss: 0.0099, time elapsed = 0.43 s
# Epoch loss slope: [-1.02879652e-05]
# Epoch validation loss slope: [-9.85973238e-06]
# Epoch [307/4000], loss: 0.0091, validation loss: 0.0098, time elapsed = 0.42 s
# Epoch loss slope: [-1.02232456e-05]
# Epoch validation loss slope: [-9.8268077e-06]
# Epoch [308/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.42 s
# Epoch loss slope: [-1.01683576e-05]
# Epoch validation loss slope: [-9.77830239e-06]
# Epoch [309/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.42 s
# Epoch loss slope: [-1.0126706e-05]
# Epoch validation loss slope: [-9.70492199e-06]
# Epoch [310/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.45 s
# Epoch loss slope: [-1.00858102e-05]
# Epoch validation loss slope: [-9.68344737e-06]
# Epoch [311/4000], loss: 0.0090, validation loss: 0.0097, time elapsed = 0.43 s
# Epoch loss slope: [-1.00619969e-05]
# Epoch validation loss slope: [-9.7161197e-06]
# Epoch [312/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.43 s
# Epoch loss slope: [-1.00211278e-05]
# Epoch validation loss slope: [-9.70856672e-06]
# Epoch [313/4000], loss: 0.0090, validation loss: 0.0100, time elapsed = 0.43 s
# Epoch loss slope: [-1.00163711e-05]
# Epoch validation loss slope: [-9.57106373e-06]
# Epoch [314/4000], loss: 0.0091, validation loss: 0.0099, time elapsed = 0.45 s
# Epoch loss slope: [-9.9272679e-06]
# Epoch validation loss slope: [-9.42419361e-06]
# Epoch [315/4000], loss: 0.0090, validation loss: 0.0097, time elapsed = 0.45 s
# Epoch loss slope: [-9.88510176e-06]
# Epoch validation loss slope: [-9.38826037e-06]
# Epoch [316/4000], loss: 0.0090, validation loss: 0.0097, time elapsed = 0.43 s
# Epoch loss slope: [-9.83432205e-06]
# Epoch validation loss slope: [-9.39354356e-06]
# Epoch [317/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.44 s
# Epoch loss slope: [-9.80864869e-06]
# Epoch validation loss slope: [-9.35450691e-06]
# Epoch [318/4000], loss: 0.0090, validation loss: 0.0098, time elapsed = 0.44 s
# Epoch loss slope: [-9.7495997e-06]
# Epoch validation loss slope: [-9.23532256e-06]
# Epoch [319/4000], loss: 0.0090, validation loss: 0.0097, time elapsed = 0.43 s
# Epoch loss slope: [-9.70575069e-06]
# Epoch validation loss slope: [-9.15386419e-06]
# Epoch [320/4000], loss: 0.0090, validation loss: 0.0097, time elapsed = 0.45 s
# Epoch loss slope: [-9.67268228e-06]
# Epoch validation loss slope: [-9.09519469e-06]
# Epoch [321/4000], loss: 0.0090, validation loss: 0.0097, time elapsed = 0.44 s
# Epoch loss slope: [-9.60538674e-06]
# Epoch validation loss slope: [-9.10224138e-06]
# Epoch [322/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.45 s
# Epoch loss slope: [-9.58599077e-06]
# Epoch validation loss slope: [-9.1007705e-06]
# Epoch [323/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.44 s
# Epoch loss slope: [-9.57369571e-06]
# Epoch validation loss slope: [-9.10562205e-06]
# Epoch [324/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.44 s
# Epoch loss slope: [-9.56853867e-06]
# Epoch validation loss slope: [-9.10711915e-06]
# Epoch [325/4000], loss: 0.0089, validation loss: 0.0097, time elapsed = 0.44 s
# Epoch loss slope: [-9.55692643e-06]
# Epoch validation loss slope: [-9.08036283e-06]
# Epoch [326/4000], loss: 0.0089, validation loss: 0.0097, time elapsed = 0.44 s
# Epoch loss slope: [-9.54097286e-06]
# Epoch validation loss slope: [-9.06632403e-06]
# Epoch [327/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.45 s
# Epoch loss slope: [-9.52574297e-06]
# Epoch validation loss slope: [-9.0825243e-06]
# Epoch [328/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.46 s
# Epoch loss slope: [-9.50282699e-06]
# Epoch validation loss slope: [-9.09343841e-06]
# Epoch [329/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.52 s
# Epoch loss slope: [-9.46219875e-06]
# Epoch validation loss slope: [-9.05350255e-06]
# Epoch [330/4000], loss: 0.0089, validation loss: 0.0097, time elapsed = 0.51 s
# Epoch loss slope: [-9.43643924e-06]
# Epoch validation loss slope: [-9.01985952e-06]
# Epoch [331/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.49 s
# Epoch loss slope: [-9.38380983e-06]
# Epoch validation loss slope: [-9.02417682e-06]
# Epoch [332/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.48 s
# Epoch loss slope: [-9.35431022e-06]
# Epoch validation loss slope: [-8.96421505e-06]
# Epoch [333/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.52 s
# Epoch loss slope: [-9.29464378e-06]
# Epoch validation loss slope: [-8.91521149e-06]
# Epoch [334/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.49 s
# Epoch loss slope: [-9.25686713e-06]
# Epoch validation loss slope: [-8.89395898e-06]
# Epoch [335/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.52 s
# Epoch loss slope: [-9.17180199e-06]
# Epoch validation loss slope: [-8.86720999e-06]
# Epoch [336/4000], loss: 0.0089, validation loss: 0.0096, time elapsed = 0.53 s
# Epoch loss slope: [-9.12479254e-06]
# Epoch validation loss slope: [-8.82289939e-06]
# Epoch [337/4000], loss: 0.0089, validation loss: 0.0095, time elapsed = 0.55 s
# Epoch loss slope: [-9.08077575e-06]
# Epoch validation loss slope: [-8.76828566e-06]
# Epoch [338/4000], loss: 0.0088, validation loss: 0.0096, time elapsed = 0.61 s
# Epoch loss slope: [-9.03266078e-06]
# Epoch validation loss slope: [-8.76881082e-06]
# Epoch [339/4000], loss: 0.0088, validation loss: 0.0096, time elapsed = 0.58 s
# Epoch loss slope: [-8.98585731e-06]
# Epoch validation loss slope: [-8.76632018e-06]
# Epoch [340/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.51 s
# Epoch loss slope: [-8.95548829e-06]
# Epoch validation loss slope: [-8.70561317e-06]
# Epoch [341/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.56 s
# Epoch loss slope: [-8.9193324e-06]
# Epoch validation loss slope: [-8.67033596e-06]
# Epoch [342/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.65 s
# Epoch loss slope: [-8.87344362e-06]
# Epoch validation loss slope: [-8.68304406e-06]
# Epoch [343/4000], loss: 0.0088, validation loss: 0.0096, time elapsed = 0.69 s
# Epoch loss slope: [-8.8263402e-06]
# Epoch validation loss slope: [-8.59848183e-06]
# Epoch [344/4000], loss: 0.0088, validation loss: 0.0096, time elapsed = 0.66 s
# Epoch loss slope: [-8.7601411e-06]
# Epoch validation loss slope: [-8.49527111e-06]
# Epoch [345/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.57 s
# Epoch loss slope: [-8.69524853e-06]
# Epoch validation loss slope: [-8.48669029e-06]
# Epoch [346/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.49 s
# Epoch loss slope: [-8.63665158e-06]
# Epoch validation loss slope: [-8.44700311e-06]
# Epoch [347/4000], loss: 0.0088, validation loss: 0.0096, time elapsed = 0.45 s
# Epoch loss slope: [-8.60866047e-06]
# Epoch validation loss slope: [-8.36719477e-06]
# Epoch [348/4000], loss: 0.0088, validation loss: 0.0096, time elapsed = 0.44 s
# Epoch loss slope: [-8.53581909e-06]
# Epoch validation loss slope: [-8.31081932e-06]
# Epoch [349/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.53 s
# Epoch loss slope: [-8.4675117e-06]
# Epoch validation loss slope: [-8.29355988e-06]
# Epoch [350/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.52 s
# Epoch loss slope: [-8.38704155e-06]
# Epoch validation loss slope: [-8.2718705e-06]
# Epoch [351/4000], loss: 0.0088, validation loss: 0.0095, time elapsed = 0.55 s
# Epoch loss slope: [-8.34464893e-06]
# ...
# Epoch loss slope: [-9.91292691e-08]
# Epoch validation loss slope: [1.57365796e-08]
# Epoch [1965/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-9.10570747e-08]
# Epoch validation loss slope: [2.73122961e-08]
# Epoch [1966/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [-9.28206185e-08]
# Epoch validation loss slope: [5.86533545e-08]
# Epoch [1967/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-8.91696083e-08]
# Epoch validation loss slope: [6.20137832e-08]
# Epoch [1968/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-9.29319848e-08]
# Epoch validation loss slope: [6.55109176e-08]
# Epoch [1969/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-9.45983698e-08]
# Epoch validation loss slope: [7.74444766e-08]
# Epoch [1970/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-8.33823555e-08]
# Epoch validation loss slope: [8.13181302e-08]
# Epoch [1971/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-9.38729944e-08]
# Epoch validation loss slope: [9.07141495e-08]
# Epoch [1972/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [-9.87357724e-08]
# Epoch validation loss slope: [9.92836696e-08]
# Epoch [1973/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.07873423e-07]
# Epoch validation loss slope: [9.19091261e-08]
# Epoch [1974/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.13001e-07]
# Epoch validation loss slope: [7.80778039e-08]
# Epoch [1975/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-1.20384539e-07]
# Epoch validation loss slope: [6.47439191e-08]
# Epoch [1976/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.29866322e-07]
# Epoch validation loss slope: [3.92065679e-08]
# Epoch [1977/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-1.42201284e-07]
# Epoch validation loss slope: [1.6915506e-08]
# Epoch [1978/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [-1.57208388e-07]
# Epoch validation loss slope: [2.89161548e-09]
# Epoch [1979/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.71262948e-07]
# Epoch validation loss slope: [-2.18408752e-08]
# Epoch [1980/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.72604491e-07]
# Epoch validation loss slope: [-4.23453793e-08]
# Epoch [1981/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.58466751e-07]
# Epoch validation loss slope: [-4.26965603e-08]
# Epoch [1982/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.56713052e-07]
# Epoch validation loss slope: [-4.77266969e-08]
# Epoch [1983/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-1.60531203e-07]
# Epoch validation loss slope: [-4.85112321e-08]
# Epoch [1984/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [-1.69891271e-07]
# Epoch validation loss slope: [-6.00878763e-08]
# Epoch [1985/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.77415652e-07]
# Epoch validation loss slope: [-6.38617585e-08]
# Epoch [1986/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.88605178e-07]
# Epoch validation loss slope: [-6.92822515e-08]
# Epoch [1987/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.75275889e-07]
# Epoch validation loss slope: [-5.0701486e-08]
# Epoch [1988/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.51650198e-07]
# Epoch validation loss slope: [-4.92359928e-08]
# Epoch [1989/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-1.43056063e-07]
# Epoch validation loss slope: [-3.80460333e-08]
# Epoch [1990/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [-1.47874996e-07]
# Epoch validation loss slope: [-1.6648566e-08]
# Epoch [1991/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.43475981e-07]
# Epoch validation loss slope: [-2.79610812e-09]
# Epoch [1992/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.4481043e-07]
# Epoch validation loss slope: [7.1362222e-09]
# Epoch [1993/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.32588976e-07]
# Epoch validation loss slope: [4.40434992e-08]
# Epoch [1994/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-1.30909494e-07]
# Epoch validation loss slope: [6.11903186e-08]
# Epoch [1995/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-1.31188938e-07]
# Epoch validation loss slope: [6.91111318e-08]
# Epoch [1996/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.43 s
# Epoch loss slope: [-1.2554325e-07]
# Epoch validation loss slope: [6.41855503e-08]
# Epoch [1997/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-1.00178606e-07]
# Epoch validation loss slope: [5.90658189e-08]
# Epoch [1998/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-5.98353568e-08]
# Epoch validation loss slope: [4.19753092e-08]
# Epoch [1999/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-3.99367271e-08]
# Epoch validation loss slope: [2.83189236e-08]
# Epoch [2000/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-4.28885527e-08]
# Epoch validation loss slope: [4.01812964e-08]
# Epoch [2001/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-3.94458819e-08]
# Epoch validation loss slope: [4.98115686e-08]
# Epoch [2002/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [-4.24825638e-08]
# Epoch validation loss slope: [7.87435668e-08]
# Epoch [2003/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-3.50255626e-08]
# Epoch validation loss slope: [7.03294404e-08]
# Epoch [2004/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-3.30665476e-08]
# Epoch validation loss slope: [5.89084972e-08]
# Epoch [2005/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-4.74115471e-08]
# Epoch validation loss slope: [4.56836105e-08]
# Epoch [2006/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-3.0441893e-08]
# Epoch validation loss slope: [3.76595051e-08]
# Epoch [2007/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-2.71666981e-08]
# Epoch validation loss slope: [1.93237894e-08]
# Epoch [2008/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [-3.93205502e-08]
# Epoch validation loss slope: [5.08715606e-09]
# Epoch [2009/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [-2.11919861e-08]
# Epoch validation loss slope: [8.02042259e-09]
# Epoch [2010/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.41 s
# Epoch loss slope: [-1.71565275e-08]
# Epoch validation loss slope: [-6.06902098e-09]
# Epoch [2011/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.42 s
# Epoch loss slope: [-2.57122993e-08]
# Epoch validation loss slope: [-1.78654662e-08]
# Epoch [2012/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-3.04298168e-08]
# Epoch validation loss slope: [-2.62712658e-08]
# Epoch [2013/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [-3.42731368e-08]
# Epoch validation loss slope: [-2.68238338e-08]
# Epoch [2014/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [-3.09818601e-08]
# Epoch validation loss slope: [6.45881846e-09]
# Epoch [2015/4000], loss: 0.0076, validation loss: 0.0084, time elapsed = 0.42 s
# Epoch loss slope: [2.88381612e-09]
# Epoch validation loss slope: [5.44879312e-08]
# Epoch [2016/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [6.04482817e-08]
# Epoch validation loss slope: [9.63634243e-08]
# Epoch [2017/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [9.17211536e-08]
# Epoch validation loss slope: [1.13356275e-07]
# Epoch [2018/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.1669009e-07]
# Epoch validation loss slope: [1.21618596e-07]
# Epoch [2019/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.37125867e-07]
# Epoch validation loss slope: [1.29706611e-07]
# Epoch [2020/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [1.55242542e-07]
# Epoch validation loss slope: [1.4310962e-07]
# Epoch [2021/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.6187172e-07]
# Epoch validation loss slope: [1.50587919e-07]
# Epoch [2022/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.63773771e-07]
# Epoch validation loss slope: [1.47887084e-07]
# Epoch [2023/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.52431181e-07]
# Epoch validation loss slope: [1.20919006e-07]
# Epoch [2024/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.4801458e-07]
# Epoch validation loss slope: [9.95795133e-08]
# Epoch [2025/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [1.54942547e-07]
# Epoch validation loss slope: [9.71365589e-08]
# Epoch [2026/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [1.60782246e-07]
# Epoch validation loss slope: [7.66901696e-08]
# Epoch [2027/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.52091445e-07]
# Epoch validation loss slope: [5.17688828e-08]
# Epoch [2028/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.47821551e-07]
# Epoch validation loss slope: [3.62577822e-08]
# Epoch [2029/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.30524011e-07]
# Epoch validation loss slope: [2.29260769e-08]
# Epoch [2030/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.11993743e-07]
# Epoch validation loss slope: [7.86907499e-09]
# Epoch [2031/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.45 s
# Epoch loss slope: [9.58733826e-08]
# Epoch validation loss slope: [5.39594496e-08]
# Epoch [2032/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [1.03255729e-07]
# Epoch validation loss slope: [8.82021269e-08]
# Epoch [2033/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.2306468e-07]
# Epoch validation loss slope: [1.00100959e-07]
# Epoch [2034/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [1.15654565e-07]
# Epoch validation loss slope: [7.2192119e-08]
# Epoch [2035/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.05182106e-07]
# Epoch validation loss slope: [5.74840962e-08]
# Epoch [2036/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [1.13173519e-07]
# Epoch validation loss slope: [3.87724816e-08]
# Epoch [2037/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [1.07767958e-07]
# Epoch validation loss slope: [1.05621145e-08]
# Epoch [2038/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [1.2297603e-07]
# Epoch validation loss slope: [6.82532309e-09]
# Epoch [2039/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.18905424e-07]
# Epoch validation loss slope: [-9.05114213e-09]
# Epoch [2040/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.14247204e-07]
# Epoch validation loss slope: [-2.63774137e-09]
# Epoch [2041/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [1.12421954e-07]
# Epoch validation loss slope: [-1.54758037e-08]
# Epoch [2042/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [9.29786779e-08]
# Epoch validation loss slope: [-9.05560175e-09]
# Epoch [2043/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.41 s
# Epoch loss slope: [8.0249082e-08]
# Epoch validation loss slope: [8.71731342e-09]
# Epoch [2044/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [8.68828924e-08]
# Epoch validation loss slope: [3.91611447e-08]
# Epoch [2045/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [9.7077125e-08]
# Epoch validation loss slope: [4.30894929e-08]
# Epoch [2046/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [9.47416839e-08]
# Epoch validation loss slope: [4.01498331e-08]
# Epoch [2047/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [6.94748084e-08]
# Epoch validation loss slope: [7.02574661e-08]
# Epoch [2048/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [6.95446925e-08]
# Epoch validation loss slope: [7.95976396e-08]
# Epoch [2049/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.42 s
# Epoch loss slope: [5.43302316e-08]
# Epoch validation loss slope: [8.56352477e-08]
# Epoch [2050/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [3.5011234e-08]
# Epoch validation loss slope: [7.94867974e-08]
# Epoch [2051/4000], loss: 0.0076, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [6.26039977e-08]
# Epoch validation loss slope: [6.39067236e-08]
# Epoch [2052/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.43 s
# Epoch loss slope: [7.34004055e-08]
# Epoch validation loss slope: [2.68613437e-08]
# Epoch [2053/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.43 s
# Epoch loss slope: [5.49959048e-08]
# Epoch validation loss slope: [-6.62081214e-09]
# Epoch [2054/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.51 s
# Epoch loss slope: [3.8953221e-08]
# Epoch validation loss slope: [-2.78025188e-08]
# Epoch [2055/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.46 s
# Epoch loss slope: [3.44937525e-08]
# Epoch validation loss slope: [-6.67220729e-08]
# Epoch [2056/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.46 s
# Epoch loss slope: [1.00814667e-08]
# Epoch validation loss slope: [-1.2050496e-07]
# Epoch [2057/4000], loss: 0.0075, validation loss: 0.0082, time elapsed = 0.43 s
# Epoch loss slope: [-2.27104911e-08]
# Epoch validation loss slope: [-1.6269808e-07]
# Epoch [2058/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [-4.02265926e-08]
# Epoch validation loss slope: [-1.79159532e-07]
# Epoch [2059/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [-4.78228569e-08]
# Epoch validation loss slope: [-1.73012597e-07]
# Epoch [2060/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.45 s
# Epoch loss slope: [-3.56217637e-08]
# Epoch validation loss slope: [-1.59351561e-07]
# Epoch [2061/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.44 s
# Epoch loss slope: [-2.39066366e-08]
# Epoch validation loss slope: [-1.41960374e-07]
# Epoch [2062/4000], loss: 0.0075, validation loss: 0.0083, time elapsed = 0.49 s
# Epoch loss slope: [-2.78330488e-08]
# Epoch validation loss slope: [-1.30652061e-07]

# %%
# loss_file = np.load("../testing/autoencoder_2026-06-25 15:51:15.363896_loss.npz")
# epoch_loss = loss_file['epoch_loss']
# epoch_loss_val = loss_file['epoch_loss_val']

plt.plot(epoch_loss)
plt.plot(epoch_loss_val)
plt.gca().set_yscale('log')

# %%
reg = sklearn.linear_model.LinearRegression()
reg_coef_all = []
reg_coef_all_val = []

window_size = 200

for i in np.arange(window_size, epoch_loss_val.shape[0]-window_size):
    x = np.arange(epoch_loss_val[i:i+window_size].shape[0])
    
    reg.fit(x.reshape(-1, 1), epoch_loss[i:i+window_size])
    reg_coef_all.append(reg.coef_)

    reg.fit(x.reshape(-1, 1), epoch_loss_val[i:i+window_size])
    reg_coef_all_val.append(reg.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 7
#       3 reg_coef_all_val = []
#       4
#       5 window_size = 200
#       6
# ----> 7 for i in np.arange(window_size, epoch_loss_val.shape[0]-window_size):
#       8     x = np.arange(epoch_loss_val[i:i+window_size].shape[0])
#       9
#      10     reg.fit(x.reshape(-1, 1), epoch_loss[i:i+window_size])
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
plt.plot(reg_coef_all)
#plt.plot(reg_coef_all_val)
plt.plot(np.ones(len(reg_coef_all)) * 1e-6)
plt.plot(np.ones(len(reg_coef_all)) * -1e-6)
plt.ylim((-2e-5, 2e-5))
# Out:
# (-2e-05, 2e-05)

# %%
plt.plot((attenu_fromEm_train_dataset[0][0] - attenu_fromEm_train_dataset[10][0]).detach().numpy().flatten())

# %%
# state_dict = torch.load('../testing/autoencoder_2026-06-25 15:51:15.000658.pth')
# model = Autoencoder(image_dimension = attenu_fromEm_standard.shape[2], kernel_1_size = 3, kernel_2_size = 5)
# model.load_state_dict(state_dict)

# %%
figs, axs = plt.subplots(1, 3, figsize = (10, 5))

idx = 10

vmin = -2
vmax = 2

im0 = axs[0].imshow(model.main(attenu_fromEm_train_dataset[idx][0]).detach().numpy()[0, 0, :, :], vmin = vmin, vmax = vmax)
axs[0].invert_yaxis()
axs[0].axis('off')
axs[0].set_title("reconstruction")
plt.colorbar(im0)

im1 = axs[1].imshow(attenu_fromEm_train_dataset[idx][0].detach().numpy()[0, :, :], vmin = vmin, vmax = vmax)
axs[1].invert_yaxis()
axs[1].axis('off')
axs[1].set_title("original")
plt.colorbar(im1)

im2 = axs[2].imshow((model.main(attenu_fromEm_train_dataset[idx][0]) - attenu_fromEm_train_dataset[idx][0]).detach().numpy()[0, 0, :, :])
axs[2].invert_yaxis()
axs[2].axis('off')
axs[2].set_title("reconstruction error")
plt.colorbar(im2)

# %%
figs, axs = plt.subplots(2, 2, figsize = (10, 10))

idx = [0, 10]

reconstruct_0 = model.main(attenu_fromEm_test_dataset[idx[0]][0]).detach().numpy()[0, 0, :, :]
original_0 = attenu_fromEm_test_dataset[idx[0]][1].detach().numpy()[0, :, :]

reconstruct_1 = model.main(attenu_fromEm_test_dataset[idx[1]][0]).detach().numpy()[0, 0, :, :]
original_1 = attenu_fromEm_test_dataset[idx[1]][1].detach().numpy()[0, :, :]

im0 = axs[0, 0].imshow(reconstruct_0, vmin = -2, vmax = 2)
axs[0, 0].invert_yaxis()
axs[0, 0].axis('off')
axs[0, 0].set_title(f"reconstruction idx{idx[0]}")
plt.colorbar(im0)

im1 = axs[0, 1].imshow(original_0, vmin = -2, vmax = 2)
axs[0, 1].invert_yaxis()
axs[0, 1].axis('off')
axs[0, 1].set_title(f"original idx{idx[0]}")
plt.colorbar(im1)

im2 = axs[1, 0].imshow(reconstruct_1, vmin = -2, vmax = 2)
axs[1, 0].invert_yaxis()
axs[1, 0].axis('off')
axs[1, 0].set_title(f"reconstruction idx{idx[1]}")
plt.colorbar(im2)

im2 = axs[1, 1].imshow(original_1, vmin = -2, vmax = 2)
axs[1, 1].invert_yaxis()
axs[1, 1].axis('off')
axs[1, 1].set_title(f"original idx{idx[1]}")
plt.colorbar(im2)

# %%
plt.plot(original_1.flatten())
plt.plot(reconstruct_1.flatten(), alpha = 0.5)

# %%
plt.plot((model.main(attenu_fromEm_test_dataset[0][0]) - model.main(attenu_fromEm_test_dataset[1][0])).detach().numpy().flatten())

# %%
var_reconstruct = np.nanvar(model.main(attenu_fromEm_test_dataset[:][0]).detach().numpy(), axis = 0)[0, :, :]
var_original = np.nanvar(attenu_fromEm_test_dataset[:][0].detach().numpy(), axis = 0)[0, :, :]

figs, axs = plt.subplots(1, 2, figsize = (10, 5))

vmin = 0
vmax = 0.05

im0 = axs[0].imshow(var_reconstruct, vmin = vmin, vmax = vmax)
axs[0].invert_yaxis()
axs[0].axis('off')
axs[0].set_title("reconstruction")
plt.colorbar(im0)

im1 = axs[1].imshow(var_original, vmin = vmin, vmax = vmax)
axs[1].invert_yaxis()
axs[1].axis('off')
axs[1].set_title("original")
plt.colorbar(im1)

# %%
plt.plot(original_1.flatten() - original_0.flatten())
plt.plot(reconstruct_1.flatten() - reconstruct_0.flatten())

# %%
# attenu_latent = model.encoder(attenu_fromEm_standard)

# torch.save(attenu_latent, 'attenu_latent.pt')
# torch.save(model.state_dict(), f'autoencoder_{datetime.datetime.now()}.pth')
